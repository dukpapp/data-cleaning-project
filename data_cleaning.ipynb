# %%
import pandas as pd

# %%
df = pd.read_csv("../data/synthetic_dataset.csv")
df.head()
# Out:
#   Category   Price    Rating         Stock  Discount
# 0      NaN  5548.0  1.870322           NaN       0.0
# 1      NaN  3045.0  4.757798           NaN      38.0
# 2      NaN  4004.0       NaN      In Stock       0.0
# 3      NaN  4808.0  1.492085           NaN      33.0
# 4      NaN  1817.0       NaN  Out of Stock      23.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4362 entries, 0 to 4361
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Category  1614 non-null   object
#  1   Price     4188 non-null   float64
#  2   Rating    2312 non-null   float64
#  3   Stock     3010 non-null   object
#  4   Discount  3970 non-null   float64
# dtypes: float64(3), object(2)
# memory usage: 170.5+ KB

# %%
df.isnull().sum()
# Out:
# Category    2748
# Price        174
# Rating      2050
# Stock       1352
# Discount     392
# dtype: int64

# %%
df["Category"] = df["Category"].astype(str)
df["Category"].replace(["nan", "None", ""], "Unknown")
df["Category"].fillna("Unknown")
# Out:
# 0       nan
# 1       nan
# 2       nan
# 3       nan
# 4       nan
#        ...
# 4357    nan
# 4358      B
# 4359    nan
# 4360      D
# 4361    nan
# Name: Category, Length: 4362, dtype: object

# %%
df["Price"] = pd.to_numeric(df["Price"], errors="coerce")
df["Price"].fillna(df["Price"].mean(), inplace=True)
# Out:
# /var/folders/4v/611n38gs6v753p2xcswlbm9h0000gn/T/ipykernel_784/2279901689.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Price"].fillna(df["Price"].mean(), inplace=True)

# %%
df["Rating"] = pd.to_numeric(df["Rating"], errors="coerce")
df["Rating"].fillna(df["Rating"].mean(), inplace=True)
# Out:
# /var/folders/4v/611n38gs6v753p2xcswlbm9h0000gn/T/ipykernel_784/1671208781.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Rating"].fillna(df["Rating"].mean(), inplace=True)

# %%
df["Discount"] = pd.to_numeric(df["Discount"], errors="coerce")
df["Discount"].fillna(df["Discount"].mean(), inplace=True)
# Out:
# /var/folders/4v/611n38gs6v753p2xcswlbm9h0000gn/T/ipykernel_784/2205721811.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Discount"].fillna(df["Discount"].mean(), inplace=True)

# %%
df["Stock"] = df["Stock"].astype(str)
df["Stock"] = df["Stock"].str.replace(r"[^0-9]", "", regex=True)
df["Stock"] = pd.to_numeric(df["Stock"], errors="coerce")
df["Stock"].fillna(df["Stock"].mean())
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#         ..
# 4357   NaN
# 4358   NaN
# 4359   NaN
# 4360   NaN
# 4361   NaN
# Name: Stock, Length: 4362, dtype: float64

# %%
df["Stock"] = df["Stock"].fillna(0)

# %%
df.isnull().sum()
# Out:
# Category    0
# Price       0
# Rating      0
# Stock       0
# Discount    0
# dtype: int64
